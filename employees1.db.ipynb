# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("employees.db")
cursor = conn.cursor()

# %%
conn.execute("""
CREATE TABLE employee
emp_id integer primarykey
name text
department text
salary real
years_experience integer
""")
