# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# # Task - 1

# %%
user_profile = {
    "name" : "shivavarshini",
    "age" : 20,
    "email" : "shivavarshinigoudkasula@gmail.com",
    "is_active" : True,
    "skills" : ["python","numpy","pandas","sql"]
}

# %%
s = json.dumps(user_profile)
print(s)

# %% [markdown]
# # Task - 2

# %%
{"status": "success", "data": {"user_id": 101, "username": "alex99", "score": 87.5}}

# %%
username = data["data"]["username"]
username

# %%
score = data["data"]["score"]
score

# %%
print(f"User {username} scored {score} points")

# %% [markdown]
# # Task - 3

# %%
data = {
  "name": "Priya",
  "address": {
    "city": "Bengaluru",
    "state": "Karnataka",
    "zip": "560001"
  }
}

# %%
print(data["address"]["city"])

# %%
print(data["address"]["zip"])

# %%
data["address"]["country"] = "india"

# %%
print(f"the updated JSON is \n{data}")
